# %%
import pandas as pd
import numpy as np
import pickle

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
df=pd.read_csv("Dataset/Raw/Std_dataset.csv")
df.head()
# Out:
#   Students age  Gender     Relationship status               Department  \
# 0  24-26 years  Female  In a love relationship                   Edtech
# 1  21-23 years    Male                  Single  Educational Technology
# 2  21-23 years    Male                  Single     Textile Engineering
# 3  24-26 years    Male  In a love relationship     Textile Engineering
# 4  21-23 years    Male                  Single                      EEE
#
#   Type of University      Father's education      Mother's education  \
# 0             Public               M.Sc/M.A.               M.Sc/M.A.
# 1             Public  B.A./B.Sc./Hons/Degree  B.A./B.Sc./Hons/Degree
# 2             Public        Secondary School        Secondary School
# 3             Public  B.A./B.Sc./Hons/Degree                 College
# 4            Private                 College        Secondary School
#
#   Father's Occupation Mother's Occupation Family Income(monthly)  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872 entries, 0 to 871
# Data columns (total 32 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Students age                                           872 non-null    object
#  1   Gender                                                 872 non-null    object
#  2   Relationship status                                    872 non-null    object
#  3   Department                                             872 non-null    object
#  4   Type of University                                     872 non-null    object
#  5   Father's education                                     872 non-null    object
#  6   Mother's education                                     872 non-null    object
#  7   Father's Occupation                                    872 non-null    object
# ...

# %%
df['Students age'].unique()
# Out:
# array(['24-26 years', '21-23 years', 'Above 26', '18-20 years'],
#       dtype=object)

# %%
encoder_Student_age=OrdinalEncoder(categories=[['18-20 years','21-23 years','24-26 years','Above 26']])
df1=encoder_Student_age.fit_transform(df[['Students age']])
df1=pd.Series(df1.flatten().astype(int))

# %%
with open('Models/encoder_Students_age.pkl', 'wb') as file:
    pickle.dump(encoder_Student_age,file)

# %%
df['Students age']=df1

# %%
df.head()
# Out:
#    Students age  Gender     Relationship status               Department  \
# 0             2  Female  In a love relationship                   Edtech
# 1             1    Male                  Single  Educational Technology
# 2             1    Male                  Single     Textile Engineering
# 3             2    Male  In a love relationship     Textile Engineering
# 4             1    Male                  Single                      EEE
#
#   Type of University      Father's education      Mother's education  \
# 0             Public               M.Sc/M.A.               M.Sc/M.A.
# 1             Public  B.A./B.Sc./Hons/Degree  B.A./B.Sc./Hons/Degree
# 2             Public        Secondary School        Secondary School
# 3             Public  B.A./B.Sc./Hons/Degree                 College
# 4            Private                 College        Secondary School
#
#   Father's Occupation Mother's Occupation Family Income(monthly)  ...  \
# ...

# %%
encoder_Gender=OrdinalEncoder(categories=[['Male', 'Female']])
df2=encoder_Gender.fit_transform(df[['Gender']])
df2=pd.Series(df2.flatten().astype(int))

# %%
with open('Models/encoder_Gender.pkl', 'wb') as file:
    pickle.dump(encoder_Gender,file)

# %%
df['Gender']=df2

# %%
df.head()
# Out:
#    Students age  Gender     Relationship status               Department  \
# 0             2       1  In a love relationship                   Edtech
# 1             1       0                  Single  Educational Technology
# 2             1       0                  Single     Textile Engineering
# 3             2       0  In a love relationship     Textile Engineering
# 4             1       0                  Single                      EEE
#
#   Type of University      Father's education      Mother's education  \
# 0             Public               M.Sc/M.A.               M.Sc/M.A.
# 1             Public  B.A./B.Sc./Hons/Degree  B.A./B.Sc./Hons/Degree
# 2             Public        Secondary School        Secondary School
# 3             Public  B.A./B.Sc./Hons/Degree                 College
# 4            Private                 College        Secondary School
#
#   Father's Occupation Mother's Occupation Family Income(monthly)  ...  \
# ...

# %%
df['Relationship status'].unique()
# Out:
# array(['In a love relationship', 'Single', 'Married'], dtype=object)

# %%
encoder_Relationship_status=OrdinalEncoder(categories=[['Single', 'In a love relationship', 'Married']])
df3=encoder_Relationship_status.fit_transform(df[['Relationship status']])
df3=pd.Series(df3.flatten().astype(int))

# %%
with open('Models/encoder_Relationship_status.pkl', 'wb') as file:
    pickle.dump(encoder_Relationship_status,file)

# %%
df['Relationship status']=df3
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#   Type of University      Father's education      Mother's education  \
# 0             Public               M.Sc/M.A.               M.Sc/M.A.
# 1             Public  B.A./B.Sc./Hons/Degree  B.A./B.Sc./Hons/Degree
# 2             Public        Secondary School        Secondary School
# 3             Public  B.A./B.Sc./Hons/Degree                 College
# 4            Private                 College        Secondary School
#
#   Father's Occupation Mother's Occupation Family Income(monthly)  ...  \
# ...

# %%
len(df['Department'].unique())
# Out:
# 149

# %%
df['Type of University'].unique()
# Out:
# array(['Public', 'Private', 'Others'], dtype=object)

# %%
encoder_Type_of_University=OrdinalEncoder(categories=[['Public', 'Private', 'Others']])
df1=encoder_Type_of_University.fit_transform(df[["Type of University"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Type_of_University.pkl', 'wb') as file:
    pickle.dump(encoder_Type_of_University,file)
df["Type of University"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University      Father's education      Mother's education  \
# 0                   0               M.Sc/M.A.               M.Sc/M.A.
# 1                   0  B.A./B.Sc./Hons/Degree  B.A./B.Sc./Hons/Degree
# 2                   0        Secondary School        Secondary School
# 3                   0  B.A./B.Sc./Hons/Degree                 College
# 4                   1                 College        Secondary School
#
#   Father's Occupation Mother's Occupation Family Income(monthly)  ...  \
# ...

# %%
df["Father's education"].unique()
# Out:
# array(['M.Sc/M.A.', 'B.A./B.Sc./Hons/Degree', 'Secondary School',
#        'College', 'Primary School', 'Ph.D.'], dtype=object)

# %%
encoder_Father_education=OrdinalEncoder(categories=[['Primary School', 'Secondary School', 'College', 'B.A./B.Sc./Hons/Degree', 'M.Sc/M.A.','Ph.D.']])
df1=encoder_Father_education.fit_transform(df[["Father's education"]])
df1=pd.Series(df1.flatten().astype(int))

# %%
with open('Models/encoder_Father_education.pkl', 'wb') as file:
    pickle.dump(encoder_Father_education,file)

# %%
df["Father's education"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education      Mother's education  \
# 0                   0                   4               M.Sc/M.A.
# 1                   0                   3  B.A./B.Sc./Hons/Degree
# 2                   0                   1        Secondary School
# 3                   0                   3                 College
# 4                   1                   2        Secondary School
#
#   Father's Occupation Mother's Occupation Family Income(monthly)  ...  \
# 0         Private Job         Private Job                >60,000  ...
# ...

# %%
df["Taking Class Note"].unique()
# Out:
# array(['Always', 'Sometimes', 'Never'], dtype=object)

# %%
encoder_Taking_Class_Note=OrdinalEncoder(categories=[['Never', 'Sometimes', 'Always']])
df1=encoder_Taking_Class_Note.fit_transform(df[["Taking Class Note"]])
df1=pd.Series(df1.flatten().astype(int))

# %%
with open('Models/encoder_Taking_Class_Note.pkl', 'wb') as file:
    pickle.dump(encoder_Taking_Class_Note,file)

# %%
df["Taking Class Note"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education      Mother's education  \
# 0                   0                   4               M.Sc/M.A.
# 1                   0                   3  B.A./B.Sc./Hons/Degree
# 2                   0                   1        Secondary School
# 3                   0                   3                 College
# 4                   1                   2        Secondary School
#
#   Father's Occupation Mother's Occupation Family Income(monthly)  ...  \
# 0         Private Job         Private Job                >60,000  ...
# ...

# %%
df["Mother's education"].unique()
# Out:
# array(['M.Sc/M.A.', 'B.A./B.Sc./Hons/Degree', 'Secondary School',
#        'College', 'Primary School', 'Ph.D.'], dtype=object)

# %%
encoder_Mother_education=OrdinalEncoder(categories=[['Primary School', 'Secondary School', 'College', 'B.A./B.Sc./Hons/Degree', 'M.Sc/M.A.','Ph.D.']])
df1=encoder_Mother_education.fit_transform(df[["Mother's education"]])
df1=pd.Series(df1.flatten().astype(int))

# %%
with open('Models/encoder_Mother_education.pkl', 'wb') as file:
    pickle.dump(encoder_Mother_education,file)

# %%
df["Mother's education"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#   Father's Occupation Mother's Occupation Family Income(monthly)  ...  \
# 0         Private Job         Private Job                >60,000  ...
# ...

# %%
df["Father's Occupation"].unique()
# Out:
# array(['Private Job', 'Govt. Service', 'Retired', 'Business',
#        'Self-employed'], dtype=object)

# %%
encoder_Father_occupation=OrdinalEncoder(categories=[['Private Job', 'Self-employed', 'Business', 'Govt. Service', 'Retired']])
df1=encoder_Father_occupation.fit_transform(df[["Father's Occupation"]])
df1=pd.Series(df1.flatten().astype(int))

# %%
with open('Models/encoder_Father_occupation.pkl', 'wb') as file:
    pickle.dump(encoder_Father_occupation,file)

# %%
df["Father's Occupation"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation Mother's Occupation Family Income(monthly)  ...  \
# 0                    0         Private Job                >60,000  ...
# ...

# %%
df["Mother's Occupation"].unique()
# Out:
# array(['Private Job', 'Housewife', 'Govt. Service', 'Self-employed',
#        'Business'], dtype=object)

# %%
encoder_Mother_occupation=OrdinalEncoder(categories=[['Private Job', 'Self-employed', 'Business', 'Govt. Service', 'Housewife']])
df1=encoder_Mother_occupation.fit_transform(df[["Mother's Occupation"]])
df1=pd.Series(df1.flatten().astype(int))

# %%
with open('Models/encoder_Mother_occupation.pkl', 'wb') as file:
    pickle.dump(encoder_Mother_occupation,file)

# %%
df["Mother's Occupation"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Family Income(monthly)"].unique()
# Out:
# array(['>60,000', '56000-60,000', '26,000-40,000TK', '41000-55000TK',
#        '<25,000Tk'], dtype=object)

# %%
# encoder_Family_Income_Monthly=OrdinalEncoder(categories=[['>60,000', '56000-60,000', '26,000-40,000TK', '41000-55000TK','<25,000Tk']])
# df1=encoder_Family_Income_Monthly.fit_transform(df[["Family Income(monthly)"]])
# df1=pd.Series(df1.flatten().astype(int))

# %%
# with open('Models/encoder_Family_Income_Monthly.pkl', 'wb') as file:
#     pickle.dump(encoder_Family_Income_Monthly,file)

# %%
# df["Family Income(monthly)"]=df1
# df.head()

# %%
df["Number of Siblings"].unique()
# Out:
# array(['2', '1', '3 or above', 'No Siblings'], dtype=object)

# %%
# encoder_Number_of_siblings=OrdinalEncoder(categories=[['>60,000', '56000-60,000', '26,000-40,000TK', '41000-55000TK','<25,000Tk']])
# df1=encoder_Number_of_siblings.fit_transform(df[["Number of Siblings"]])
# df1=pd.Series(df1.flatten().astype(int))

# %%
# with open('Models/encoder_Number_of_siblings.pkl', 'wb') as file:
#     pickle.dump(encoder_Number_of_siblings,file)

# %%
# df["Number of Siblings"]=df1
# df.head()

# %%
df["Parental status"].unique()
# Out:
# array(['Happily Married', 'Died-one of them or both', 'Divorced'],
#       dtype=object)

# %%
encoder_Parental_status=OrdinalEncoder(categories=[['Happily Married', 'Died-one of them or both', 'Divorced']])
df1=encoder_Parental_status.fit_transform(df[["Parental status"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Parental_status.pkl', 'wb') as file:
    pickle.dump(encoder_Parental_status,file)
df["Parental status"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Previous School Location"].unique()
# Out:
# array(['Rural', 'Urban', 'Country Town'], dtype=object)

# %%
encoder_Previous_school_location=OrdinalEncoder(categories=[['Rural', 'Urban', 'Country Town']])
df1=encoder_Previous_school_location.fit_transform(df[["Previous School Location"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Previous_school_location.pkl', 'wb') as file:
    pickle.dump(encoder_Previous_school_location,file)
df["Previous School Location"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Previous College Location"].unique()
# Out:
# array(['Urban', 'Country Town', 'Rural'], dtype=object)

# %%
encoder_Previous_college_location=OrdinalEncoder(categories=[['Rural', 'Urban', 'Country Town']])
df1=encoder_Previous_college_location.fit_transform(df[["Previous College Location"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Previous_college_location.pkl', 'wb') as file:
    pickle.dump(encoder_Previous_college_location,file)
df["Previous College Location"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["SSC result"].unique()
# Out:
# array(['GPA 5.00', 'GPA 4.00 - 4.99', 'Less than 3.00', 'GPA 3.00 - 3.99'],
#       dtype=object)

# %%
encoder_SSC_result=OrdinalEncoder(categories=[['Less than 3.00', 'GPA 3.00 - 3.99', 'GPA 4.00 - 4.99', 'GPA 5.00']])
df1=encoder_SSC_result.fit_transform(df[["SSC result"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_SSC_result.pkl', 'wb') as file:
    pickle.dump(encoder_SSC_result,file)
df["SSC result"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["HSC result"].unique()
# Out:
# array(['GPA 5.00', 'GPA 4.00 - 4.99', 'GPA 3.00 - 3.99', 'Less than 3.00'],
#       dtype=object)

# %%
encoder_HSC_result=OrdinalEncoder(categories=[['Less than 3.00', 'GPA 3.00 - 3.99', 'GPA 4.00 - 4.99', 'GPA 5.00']])
df1=encoder_HSC_result.fit_transform(df[["HSC result"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_HSC_result.pkl', 'wb') as file:
    pickle.dump(encoder_HSC_result,file)
df["HSC result"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Scholarship in SSC"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
encoder_Scholarship_in_SSC=OrdinalEncoder(categories=[['No', 'Yes']])
df1=encoder_Scholarship_in_SSC.fit_transform(df[["Scholarship in SSC"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Scholarship_in_SSC.pkl', 'wb') as file:
    pickle.dump(encoder_Scholarship_in_SSC,file)
df["Scholarship in SSC"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Scholarship in HSC"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
encoder_Scholarship_in_HSC=OrdinalEncoder(categories=[['No', 'Yes']])
df1=encoder_Scholarship_in_HSC.fit_transform(df[["Scholarship in HSC"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Scholarship_in_HSC.pkl', 'wb') as file:
    pickle.dump(encoder_Scholarship_in_HSC,file)
df["Scholarship in HSC"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Accommodation"].unique()
# Out:
# array(['University Hall', 'With family', 'Rental', 'Others'], dtype=object)

# %%
encoder_Accommodation=OrdinalEncoder(categories=[['With family', 'University Hall', 'Rental', 'Others']])
df1=encoder_Accommodation.fit_transform(df[["Accommodation"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Accommodation.pkl', 'wb') as file:
    pickle.dump(encoder_Accommodation,file)
df["Accommodation"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Weekly Study Time at home"].unique()
# Out:
# array(['11-15 Hour', '2-5 Hour', '6-10Hour', 'Less than 1 Hour',
#        '11-14 Hour', 'More than 15 Hour'], dtype=object)

# %%
encoder_Weekly_study_time_at_home=OrdinalEncoder(categories=[['Less than 1 Hour', '2-5 Hour', '6-10Hour', '11-14 Hour', '11-15 Hour', 'More than 15 Hour']])
df1=encoder_Weekly_study_time_at_home.fit_transform(df[["Weekly Study Time at home"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Weekly_study_time_at_home.pkl', 'wb') as file:
    pickle.dump(encoder_Weekly_study_time_at_home,file)
df["Weekly Study Time at home"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Reading Scientific books/articles/journals"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
encoder_Reading_Scientific_books=OrdinalEncoder(categories=[['No', 'Yes']])
df1=encoder_Reading_Scientific_books.fit_transform(df[["Reading Scientific books/articles/journals"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Reading_Scientific_books.pkl', 'wb') as file:
    pickle.dump(encoder_Reading_Scientific_books,file)
df["Reading Scientific books/articles/journals"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Attendance in class"].unique()
# Out:
# array(['More than 80%class', '60%-79% classes', 'Less than 60% classes'],
#       dtype=object)

# %%
encoder_Attendance_in_class=OrdinalEncoder(categories=[["Less than 60% classes", "60%-79% classes", "More than 80%class"]])
df1=encoder_Attendance_in_class.fit_transform(df[["Attendance in class"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Attendance_in_class.pkl', 'wb') as file:
    pickle.dump(encoder_Attendance_in_class,file)
df["Attendance in class"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Mid-Term Exam Preparation"].unique()
# Out:
# array(['Alone', 'Not applicable', 'Group study'], dtype=object)

# %%
encoder_Mid_Term_Exam_Preparation=OrdinalEncoder(categories=[['Not applicable', 'Alone', 'Group study']])
df1=encoder_Mid_Term_Exam_Preparation.fit_transform(df[["Mid-Term Exam Preparation"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Mid_Term_Exam_Preparation.pkl', 'wb') as file:
    pickle.dump(encoder_Mid_Term_Exam_Preparation,file)
df["Mid-Term Exam Preparation"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Taking Exam Preparation"].unique()
# Out:
# array(['Regular study during the semester', 'Close date to exam', 'Never'],
#       dtype=object)

# %%
encoder_Taking_Exam_Preparation=OrdinalEncoder(categories=[['Never', 'Close date to exam', 'Regular study during the semester']])
df1=encoder_Taking_Exam_Preparation.fit_transform(df[["Taking Exam Preparation"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Taking_Exam_Preparation.pkl', 'wb') as file:
    pickle.dump(encoder_Taking_Exam_Preparation,file)
df["Taking Exam Preparation"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Any Co-curricular activity"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
encoder_Any_Co_curricular_activity=OrdinalEncoder(categories=[['No', 'Yes']])
df1=encoder_Any_Co_curricular_activity.fit_transform(df[["Any Co-curricular activity"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Any_Co_curricular_activity.pkl', 'wb') as file:
    pickle.dump(encoder_Any_Co_curricular_activity,file)
df["Any Co-curricular activity"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Attend any Seminar related to department"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
encoder_Attend_any_Seminar_related_to_department=OrdinalEncoder(categories=[['No', 'Yes']])
df1=encoder_Attend_any_Seminar_related_to_department.fit_transform(df[["Attend any Seminar related to department"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Attend_any_Seminar_related_to_department.pkl', 'wb') as file:
    pickle.dump(encoder_Attend_any_Seminar_related_to_department,file)
df["Attend any Seminar related to department"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Any part-time job"].unique()
# Out:
# array(['Tution', 'Others', 'Not Applicable', 'Business'], dtype=object)

# %%
encoder_Any_part_time_job=OrdinalEncoder(categories=[['Not Applicable', 'Tution', 'Business', 'Others',]])
df1=encoder_Any_part_time_job.fit_transform(df[["Any part-time job"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Any_part_time_job.pkl', 'wb') as file:
    pickle.dump(encoder_Any_part_time_job,file)
df["Any part-time job"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Smoking"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
encoder_Smoking=OrdinalEncoder(categories=[['No', 'Yes']])
df1=encoder_Smoking.fit_transform(df[["Smoking"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Smoking.pkl', 'wb') as file:
    pickle.dump(encoder_Smoking,file)
df["Smoking"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Sports/ Exercise"].unique()
# Out:
# array(['Sometimes', 'Never', 'Always'], dtype=object)

# %%
encoder_Sports_Exercise=OrdinalEncoder(categories=[['Never', 'Sometimes', 'Always']])
df1=encoder_Sports_Exercise.fit_transform(df[["Sports/ Exercise"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Sports_Exercise.pkl', 'wb') as file:
    pickle.dump(encoder_Sports_Exercise,file)
df["Sports/ Exercise"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...

# %%
df["Undergraduate 1st semester result (CGPA/GPA out of 4)"].unique()
# Out:
# array(['3.75 - 4.00', '3.50 - 3.74', '3.25 - 3.49', '3.00 - 3.24',
#        'Less than 2.50', '2.75 - 2.99', '2.50 - 2.74', 'Fail'],
#       dtype=object)

# %%
encoder_Undergraduate_1st_semester_result=OrdinalEncoder(categories=[['Fail', 'Less than 2.50', '2.50 - 2.74', '2.75 - 2.99', '3.00 - 3.24', '3.25 - 3.49', '3.50 - 3.74', '3.75 - 4.00']])
df1=encoder_Undergraduate_1st_semester_result.fit_transform(df[["Undergraduate 1st semester result (CGPA/GPA out of 4)"]])
df1=pd.Series(df1.flatten().astype(int))
with open('Models/encoder_Undergraduate_1st_semester_result.pkl', 'wb') as file:
    pickle.dump(encoder_Undergraduate_1st_semester_result,file)
df["Undergraduate 1st semester result (CGPA/GPA out of 4)"]=df1
df.head()
# Out:
#    Students age  Gender  Relationship status               Department  \
# 0             2       1                    1                   Edtech
# 1             1       0                    0  Educational Technology
# 2             1       0                    0     Textile Engineering
# 3             2       0                    1     Textile Engineering
# 4             1       0                    0                      EEE
#
#    Type of University  Father's education  Mother's education  \
# 0                   0                   4                   4
# 1                   0                   3                   3
# 2                   0                   1                   1
# 3                   0                   3                   2
# 4                   1                   2                   1
#
#    Father's Occupation  Mother's Occupation Family Income(monthly)  ...  \
# 0                    0                    0                >60,000  ...
# ...
